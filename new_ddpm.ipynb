# %%
# install pytorch
# !pip3 install torch torchvision

# %%
# !pip install blobfile

# %%
# !conda install -y mpi4py
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.

# %%
# !python3 setup.py install
# Out:
# running install
# /home/himanshi/courses/mtp/mtp2/mtp-2/.conda/lib/python3.11/site-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /home/himanshi/courses/mtp/mtp2/mtp-2/.conda/lib/python3.11/site-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# writing guided_diffusion.egg-info/PKG-INFO
# writing dependency_links to guided_diffusion.egg-info/dependency_links.txt
# writing requirements to guided_diffusion.egg-info/requires.txt
# writing top-level names to guided_diffusion.egg-info/top_level.txt
# file guided_diffusion.py (for module guided_diffusion) not found
# reading manifest file 'guided_diffusion.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'guided_diffusion.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# file guided_diffusion.py (for module guided_diffusion) not found
# file guided_diffusion.py (for module guided_diffusion) not found
# warning: install_lib: 'build/lib' does not exist -- no Python modules to install
#
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying guided_diffusion.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying guided_diffusion.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying guided_diffusion.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying guided_diffusion.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying guided_diffusion.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating 'dist/guided_diffusion-0.0.0-py3.11.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing guided_diffusion-0.0.0-py3.11.egg
# Removing /home/himanshi/courses/mtp/mtp2/mtp-2/.conda/lib/python3.11/site-packages/guided_diffusion-0.0.0-py3.11.egg
# Copying guided_diffusion-0.0.0-py3.11.egg to /home/himanshi/courses/mtp/mtp2/mtp-2/.conda/lib/python3.11/site-packages
# Adding guided-diffusion 0.0.0 to easy-install.pth file
#
# Installed /home/himanshi/courses/mtp/mtp2/mtp-2/.conda/lib/python3.11/site-packages/guided_diffusion-0.0.0-py3.11.egg
# Processing dependencies for guided-diffusion==0.0.0
# Searching for tqdm==4.66.2
# Best match: tqdm 4.66.2
# Processing tqdm-4.66.2-py3.11.egg
# Adding tqdm 4.66.2 to easy-install.pth file
# Installing tqdm script to /home/himanshi/courses/mtp/mtp2/mtp-2/.conda/bin
#
# Using /home/himanshi/courses/mtp/mtp2/mtp-2/.conda/lib/python3.11/site-packages/tqdm-4.66.2-py3.11.egg
# Searching for torch==2.2.1
# Best match: torch 2.2.1
# Adding torch 2.2.1 to easy-install.pth file
# Installing convert-caffe2-to-onnx script to /home/himanshi/courses/mtp/mtp2/mtp-2/.conda/bin
# Installing convert-onnx-to-caffe2 script to /home/himanshi/courses/mtp/mtp2/mtp-2/.conda/bin
# Installing torchrun script to /home/himanshi/courses/mtp/mtp2/mtp-2/.conda/bin
#
# Using /home/himanshi/courses/mtp/mtp2/mtp-2/.conda/lib/python3.11/site-packages
# Searching for blobfile==2.1.1
# Best match: blobfile 2.1.1
# Adding blobfile 2.1.1 to easy-install.pth file
#
# Using /home/himanshi/courses/mtp/mtp2/mtp-2/.conda/lib/python3.11/site-packages
# Searching for triton==2.2.0
# Best match: triton 2.2.0
# Adding triton 2.2.0 to easy-install.pth file
#
# Using /home/himanshi/courses/mtp/mtp2/mtp-2/.conda/lib/python3.11/site-packages
# Searching for nvidia-nvtx-cu12==12.1.105
# Best match: nvidia-nvtx-cu12 12.1.105
# Adding nvidia-nvtx-cu12 12.1.105 to easy-install.pth file
#
# Using /home/himanshi/courses/mtp/mtp2/mtp-2/.conda/lib/python3.11/site-packages
# Searching for nvidia-nccl-cu12==2.19.3
# Best match: nvidia-nccl-cu12 2.19.3
# Adding nvidia-nccl-cu12 2.19.3 to easy-install.pth file
#
# Using /home/himanshi/courses/mtp/mtp2/mtp-2/.conda/lib/python3.11/site-packages
# Searching for nvidia-cusparse-cu12==12.1.0.106
# Best match: nvidia-cusparse-cu12 12.1.0.106
# Adding nvidia-cusparse-cu12 12.1.0.106 to easy-install.pth file
#
# Using /home/himanshi/courses/mtp/mtp2/mtp-2/.conda/lib/python3.11/site-packages
# Searching for nvidia-cusolver-cu12==11.4.5.107
# Best match: nvidia-cusolver-cu12 11.4.5.107
# Adding nvidia-cusolver-cu12 11.4.5.107 to easy-install.pth file
#
# Using /home/himanshi/courses/mtp/mtp2/mtp-2/.conda/lib/python3.11/site-packages
# Searching for nvidia-curand-cu12==10.3.2.106
# Best match: nvidia-curand-cu12 10.3.2.106
# Adding nvidia-curand-cu12 10.3.2.106 to easy-install.pth file
#
# Using /home/himanshi/courses/mtp/mtp2/mtp-2/.conda/lib/python3.11/site-packages
# Searching for nvidia-cufft-cu12==11.0.2.54
# Best match: nvidia-cufft-cu12 11.0.2.54
# Adding nvidia-cufft-cu12 11.0.2.54 to easy-install.pth file
#
# Using /home/himanshi/courses/mtp/mtp2/mtp-2/.conda/lib/python3.11/site-packages
# Searching for nvidia-cublas-cu12==12.1.3.1
# Best match: nvidia-cublas-cu12 12.1.3.1
# Adding nvidia-cublas-cu12 12.1.3.1 to easy-install.pth file
#
# Using /home/himanshi/courses/mtp/mtp2/mtp-2/.conda/lib/python3.11/site-packages
# Searching for nvidia-cudnn-cu12==8.9.2.26
# Best match: nvidia-cudnn-cu12 8.9.2.26
# Adding nvidia-cudnn-cu12 8.9.2.26 to easy-install.pth file
#
# Using /home/himanshi/courses/mtp/mtp2/mtp-2/.conda/lib/python3.11/site-packages
# Searching for nvidia-cuda-cupti-cu12==12.1.105
# Best match: nvidia-cuda-cupti-cu12 12.1.105
# Adding nvidia-cuda-cupti-cu12 12.1.105 to easy-install.pth file
#
# Using /home/himanshi/courses/mtp/mtp2/mtp-2/.conda/lib/python3.11/site-packages
# Searching for nvidia-cuda-runtime-cu12==12.1.105
# Best match: nvidia-cuda-runtime-cu12 12.1.105
# Adding nvidia-cuda-runtime-cu12 12.1.105 to easy-install.pth file
#
# Using /home/himanshi/courses/mtp/mtp2/mtp-2/.conda/lib/python3.11/site-packages
# Searching for nvidia-cuda-nvrtc-cu12==12.1.105
# Best match: nvidia-cuda-nvrtc-cu12 12.1.105
# Adding nvidia-cuda-nvrtc-cu12 12.1.105 to easy-install.pth file
#
# Using /home/himanshi/courses/mtp/mtp2/mtp-2/.conda/lib/python3.11/site-packages
# Searching for fsspec==2024.2.0
# Best match: fsspec 2024.2.0
# Adding fsspec 2024.2.0 to easy-install.pth file
#
# Using /home/himanshi/courses/mtp/mtp2/mtp-2/.conda/lib/python3.11/site-packages
# Searching for Jinja2==3.1.3
# Best match: Jinja2 3.1.3
# Adding Jinja2 3.1.3 to easy-install.pth file
#
# Using /home/himanshi/courses/mtp/mtp2/mtp-2/.conda/lib/python3.11/site-packages
# Searching for networkx==3.2.1
# Best match: networkx 3.2.1
# Adding networkx 3.2.1 to easy-install.pth file
#
# Using /home/himanshi/courses/mtp/mtp2/mtp-2/.conda/lib/python3.11/site-packages
# Searching for sympy==1.12
# Best match: sympy 1.12
# Adding sympy 1.12 to easy-install.pth file
# Installing isympy script to /home/himanshi/courses/mtp/mtp2/mtp-2/.conda/bin
#
# Using /home/himanshi/courses/mtp/mtp2/mtp-2/.conda/lib/python3.11/site-packages
# Searching for typing-extensions==4.10.0
# Best match: typing-extensions 4.10.0
# Adding typing-extensions 4.10.0 to easy-install.pth file
#
# Using /home/himanshi/courses/mtp/mtp2/mtp-2/.conda/lib/python3.11/site-packages
# Searching for filelock==3.13.1
# Best match: filelock 3.13.1
# Adding filelock 3.13.1 to easy-install.pth file
#
# Using /home/himanshi/courses/mtp/mtp2/mtp-2/.conda/lib/python3.11/site-packages
# Searching for lxml==4.9.4
# Best match: lxml 4.9.4
# Adding lxml 4.9.4 to easy-install.pth file
#
# Using /home/himanshi/courses/mtp/mtp2/mtp-2/.conda/lib/python3.11/site-packages
# Searching for urllib3==2.2.1
# Best match: urllib3 2.2.1
# Adding urllib3 2.2.1 to easy-install.pth file
#
# Using /home/himanshi/courses/mtp/mtp2/mtp-2/.conda/lib/python3.11/site-packages
# Searching for pycryptodomex==3.20.0
# Best match: pycryptodomex 3.20.0
# Adding pycryptodomex 3.20.0 to easy-install.pth file
#
# Using /home/himanshi/courses/mtp/mtp2/mtp-2/.conda/lib/python3.11/site-packages
# Searching for nvidia-nvjitlink-cu12==12.3.101
# Best match: nvidia-nvjitlink-cu12 12.3.101
# Adding nvidia-nvjitlink-cu12 12.3.101 to easy-install.pth file
#
# Using /home/himanshi/courses/mtp/mtp2/mtp-2/.conda/lib/python3.11/site-packages
# Searching for MarkupSafe==2.1.5
# Best match: MarkupSafe 2.1.5
# Adding MarkupSafe 2.1.5 to easy-install.pth file
#
# Using /home/himanshi/courses/mtp/mtp2/mtp-2/.conda/lib/python3.11/site-packages
# Searching for mpmath==1.3.0
# Best match: mpmath 1.3.0
# Adding mpmath 1.3.0 to easy-install.pth file
#
# Using /home/himanshi/courses/mtp/mtp2/mtp-2/.conda/lib/python3.11/site-packages
# Finished processing dependencies for guided-diffusion==0.0.0

# %%
MODEL_FLAGS="--image_size 64 --num_channels 128 --num_res_blocks 3"
DIFFUSION_FLAGS="--diffusion_steps 4000 --noise_schedule linear"
TRAIN_FLAGS="--lr 1e-4 --batch_size 128"

# %%
# !ls scripts
# Out:
# classifier_sample.py  image_nll.py     image_train.py	    super_res_train.py
# classifier_train.py   image_sample.py  super_res_sample.py

# %%
# !python3 scripts/image_train.py --data_dir datasets/sample_dataset --image_size 64 --num_channels 128 --num_res_blocks 3 --diffusion_steps 4000 --noise_schedule linear --lr 1e-4 --batch_size 128
# Out:
# Traceback (most recent call last):
#   File "/home/himanshi/courses/mtp/mtp2/mtp-2/scripts/image_train.py", line 7, in <module>
#     from guided_diffusion import dist_util, logger
# ModuleNotFoundError: No module named 'guided_diffusion'
