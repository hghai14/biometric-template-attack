# %%
import numpy as np

# %%
a = np.load('ffhq256_pp/test/embeddings/69001.npy')
b = np.load('warped_dataset/0_0_0/test/embeddings/00001.npy')
c = np.load('warped_dataset/0_1_3/test/embeddings/69001.npy')

# %%
a-b
# Out:
# array([[ 0.05018622,  0.00692039,  0.07290091, -0.04611654, -0.00169248,
#         -0.01284811,  0.05548408, -0.03177217, -0.01048935,  0.02754042,
#          0.07847621, -0.10560201, -0.00942685,  0.0387028 ,  0.09837307,
#          0.03093342, -0.06046592, -0.081701  , -0.08819038,  0.12382063,
#          0.03340507, -0.04852657, -0.14692718, -0.01748739, -0.08708926,
#          0.0438061 , -0.02732605,  0.07615238,  0.03519771, -0.01559382,
#          0.00685515,  0.01900524,  0.01071375,  0.00467858, -0.03070753,
#         -0.04016099, -0.01467136,  0.05960859,  0.15784818, -0.04225263,
#         -0.03183464,  0.04585424, -0.0520006 , -0.01438091,  0.08631231,
#          0.02126691, -0.01020152, -0.15635106,  0.17688441,  0.00396121,
#         -0.01469253, -0.054369  , -0.1403246 , -0.04958996, -0.01749014,
#         -0.02636282,  0.01898555, -0.17256746, -0.01966492,  0.09086289,
#          0.00543559, -0.09435628, -0.00484904, -0.03252252,  0.00211298,
# ...
